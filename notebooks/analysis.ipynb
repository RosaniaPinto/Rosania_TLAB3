# %% [markdown]
# # Analysis
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import coffee data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# import weather data
weather = pd.read_csv("../data/weather/weather_data.csv")

# %%
# TODO: Merge these two dataframes together

merged_df = pd.merge(coffee, weather, on=["year", "subdivision"], how="inner")

# %%
# TODO: View the first 5 rows of your data
merged_df.head()
# Out:
#   country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 1  Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 2  Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 3  Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 4  Brazil  Minas Gerais  Arabica      22.10  2010             873.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         5330.0             175.0            2298.0
# 1         5730.0             186.0            2245.0
# 2         5720.0             196.0            2235.0
# 3         5770.0             188.0            2223.0
# 4         5725.0             244.0            2151.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare  rain_max  \
# 0                     2319.0                        3320.0  6.670968
# 1                     2552.0                        3030.0  1.866250
# ...

# %%
# TODO: Check for null values 
print(merged_df.isnull().sum())

...
# Out:
# country                         0
# subdivision                     0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                1
# bearing_trees                   1
# nonbear_hectares                1
# bearing_hectares                1
# bearing_trees_per_hectare       1
# nonbearing_trees_per_hectare    1
# rain_max                        0
# temp_avg                        0
# temp_max                        0
# temp_min                        0
# hum_max                         0
# hum_min                         0
# wind_max                        0
# wind_avg                        0
# dtype: int64
# Ellipsis

# %%
# TODO: Drop rows that contain null values

merged_df = merged_df.dropna()
print(merged_df.isnull().sum())
# Out:
# country                         0
# subdivision                     0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                0
# bearing_trees                   0
# nonbear_hectares                0
# bearing_hectares                0
# bearing_trees_per_hectare       0
# nonbearing_trees_per_hectare    0
# rain_max                        0
# temp_avg                        0
# temp_max                        0
# temp_min                        0
# hum_max                         0
# hum_min                         0
# wind_max                        0
# wind_avg                        0
# dtype: int64

# %%
merged_df.head()
# Out:
#   country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 1  Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 2  Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 3  Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 4  Brazil  Minas Gerais  Arabica      22.10  2010             873.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         5330.0             175.0            2298.0
# 1         5730.0             186.0            2245.0
# 2         5720.0             196.0            2235.0
# 3         5770.0             188.0            2223.0
# 4         5725.0             244.0            2151.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare  rain_max  \
# 0                     2319.0                        3320.0  6.670968
# 1                     2552.0                        3030.0  1.866250
# ...

# %%
# TODO: BEGIN YOUR EDA!

#gridline got Max Rainfall over the years
x = merged_df['year']        # Typically x-axis
y = merged_df['rain_max']    # Typically y-axis

plt.title("Max Rainfall Over the Years")
plt.xlabel("Year")
plt.ylabel("Max Rainfall")

plt.plot(x, y)
plt.grid()
plt.show()

# %%
# Pairplot of coffee production data
plt.figure(figsize=(10, 6))
sns.pairplot(merged_df)
plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
sns.histplot(data=merged_df, x="temp_avg", y="year")
# Out:
# <Axes: xlabel='temp_avg', ylabel='year'>

# %%
sns.histplot(data=merged_df, x="year", y="temp_avg")
# Out:
# <Axes: xlabel='year', ylabel='temp_avg'>

# %%
merged_df['60kgs_bag'].hist(bins=20)
plt.title('60kgs Bags Frequency')
plt.xlabel('Amount of 60kgs Bags')
plt.show()

# %%
merged_df['temp_max'].hist(bins=20)
plt.title('Temperature Max Frequency')
plt.xlabel('Temperature')
plt.show()

# %%
#Histogram of Nonbearing Trees Per Hectare & Bearing Trees Per Hectare

merged_df['nonbearing_trees_per_hectare'].hist(bins=20)
plt.title('Nonbearing Trees Per Hectare Frequency')
plt.xlabel('Nonbearing Trees Per Hectare')
plt.show()

merged_df['bearing_trees_per_hectare'].hist(bins=20)
plt.title('Bearing Trees Per Hectare Frequency')
plt.xlabel('Bearing Trees Per Hectare')
plt.show()

# %%
#Histogram of Nonbearing Trees & Bearing Trees 

merged_df['nonbearing_trees'].hist(bins=20)
plt.title('Nonbearing Trees Frequency')
plt.xlabel('Nonbearing Trees')
plt.show()

merged_df['bearing_trees'].hist(bins=20)
plt.title('Bearing Trees Frequency')
plt.xlabel('Bearing Trees')
plt.show()

# %%
#Lineplot
merged_df.plot(x='year', y='bearing_trees', kind='line')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# What is the relationship between temp_avg and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between temp_av and 60kgs_bag leads to no correlation. 60kgs_bag rounds to 0 which is close to 0 instead of -1.

# %%
#Scatterplot
merged_df.plot(x='temp_avg', y='60kgs_bag', kind='scatter')
#Pearson's correlation coefficient
merged_df[["temp_avg", "60kgs_bag"]].corr()
# Out:
#            temp_avg  60kgs_bag
# temp_avg   1.000000  -0.124772
# 60kgs_bag -0.124772   1.000000

# %% [markdown]
# What is the relationship between minimum humidity and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between minimum humidity and 60kgs_bag leads to a negative correlation. 60kgs_bag rounds to -0.6 which is close to -1 instead of 0 or 1.

# %%
#Scatterplot
merged_df.plot(x='hum_min', y='60kgs_bag', kind='scatter')
#Pearson's correlation coefficient
merged_df[["hum_min", "60kgs_bag"]].corr()
# Out:
#             hum_min  60kgs_bag
# hum_min    1.000000  -0.540171
# 60kgs_bag -0.540171   1.000000

# %% [markdown]
# What is the relationship between rain_max and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between rain max and 60kgs_bag leads to no correlation. 60kgs_bag rounds to -0.4 which is close to 0 instead of -1.

# %%
#Scatterplot
merged_df.plot(x='rain_max', y='60kgs_bag', kind='scatter')
#Pearson's correlation coefficient
merged_df[["rain_max", "60kgs_bag"]].corr()
# Out:
#            rain_max  60kgs_bag
# rain_max   1.000000  -0.395811
# 60kgs_bag -0.395811   1.000000

# %% [markdown]
# What is the relationship between average wind speed and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between average wind speed and 60kgs_bag leads to a negative correlation. 60kgs_bag rounds to -0.7 which is close to -1 instead of 0 or 1.

# %%
#Scatterplot
merged_df.plot(x='wind_avg', y='60kgs_bag', kind='scatter')

#Pearson's correlation coefficient
merged_df[["wind_avg", "60kgs_bag"]].corr()
# Out:
#            wind_avg  60kgs_bag
# wind_avg   1.000000  -0.707327
# 60kgs_bag -0.707327   1.000000

# %% [markdown]
# Perform the same bivariate analysis between the mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column of your choice (bearing_trees, nonbearing_trees, bearing_trees_per_hectare, etc). Which directions do these relationships follow? What are the strengths of these relationships?
#
# The relationship between mentioned weather columns (temp_avg, hum_min, rain_max, and wind_avg) and a coffee-related column (bearing_trees) follow a negative to no correlation. The bearing trees looks like it is affected by the weather changes.

# %%
# Pairwise scatter plots for temperature average, humidity minimum, rain maximum, wind average compared to bearing trees
sns.pairplot(merged_df, vars=['temp_avg', 'hum_min', 'rain_max', 'wind_avg'], 
             y_vars=['bearing_trees'], kind='reg', height=4, aspect=1)
plt.suptitle('Scatter Plots: Weather vs Bearing Trees', y=1.02)
plt.show()

# %%
#scatterplot for temperature average and bearing trees
merged_df.plot(x='temp_avg', y='bearing_trees', kind='scatter')
#Pearson's correlation coefficient
merged_df[["bearing_trees", "temp_avg"]].corr()
# Out:
#                bearing_trees  temp_avg
# bearing_trees       1.000000 -0.426886
# temp_avg           -0.426886  1.000000

# %%
#scatterplot for humidity minimum and bearing trees
merged_df.plot(x='hum_min', y='bearing_trees', kind='scatter')
#Pearson's correlation coefficient
merged_df[["bearing_trees", "hum_min"]].corr()
# Out:
#                bearing_trees   hum_min
# bearing_trees       1.000000 -0.593017
# hum_min            -0.593017  1.000000

# %%
#scatterplot
merged_df.plot.scatter(x='nonbearing_trees', y='bearing_trees')
plt.title('Nonbearing Trees vs Bearing Trees')
plt.show()

# %%
#scatterplot for rain maximum and bearing trees
merged_df.plot(x='rain_max', y='bearing_trees', kind='scatter')
#Pearson's correlation coefficient
merged_df[["bearing_trees", "rain_max"]].corr()
# Out:
#                bearing_trees  rain_max
# bearing_trees       1.000000 -0.332832
# rain_max           -0.332832  1.000000

# %%
#scatterplot for wind average and bearing trees
merged_df.plot(x='wind_avg', y='bearing_trees', kind='scatter')
#Pearson's correlation coefficient
merged_df[["bearing_trees", "wind_avg"]].corr()
# Out:
#                bearing_trees  wind_avg
# bearing_trees       1.000000 -0.598742
# wind_avg           -0.598742  1.000000

# %% [markdown]
# Which weather factor seems to influence coffee production the most?
#
# Temperature average and rain maximum influence coffee production the most.

# %% [markdown]
# Which data would you collect to continue exploring the impacts of weather and economic forces on coffee production?
#
# I would continue to explore wind average and humidity minimum on how it negatively affects coffee production.

# %% [markdown]
# If you were preparing a report to provide coffee farmers, which weather condititions would you state are the most favorable for coffee growing (assuming any exist)?
#
# I would state that rain maximum and temperature average are the most favorable for coffee growing.
