# %% [markdown]
# # Explore Cofffee
#
# Create your own EDA below! Create as many code-blocks as you need.
#
# Once you've completed your EDA, complete the section titled **Reflections** where you will answer questions about your EDA.

# %%
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import data
coffee = pd.read_csv("../data/crop/coffee_output.csv")

# %%
# TODO: view first 5 rows of your data
coffee.head()
# Out:
#   country     subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0  Brazil    Minas Gerais  Arabica       16.2  2002            1500.0
# 1  Brazil  Espirito Santo  Arabica        2.2  2002            1500.0
# 2  Brazil  Espirito Santo  Robusta        7.5  2002            1500.0
# 3  Brazil       Sao Paulo  Arabica        3.2  2002            1500.0
# 4  Brazil          Parana  Arabica        0.5  2002            1500.0
#
#    bearing_trees  nonbear_hectares  bearing_hectares  \
# 0         4465.0             495.0            2120.0
# 1         4465.0             495.0            2120.0
# 2         4465.0             495.0            2120.0
# 3         4465.0             495.0            2120.0
# 4         4465.0             495.0            2120.0
#
#    bearing_trees_per_hectare  nonbearing_trees_per_hectare
# 0                     2106.0                        3030.0
# 1                     2106.0                        3030.0
# ...

# %%
# TODO: describe your numeric columns
coffee.describe()
# Out:
#         60kgs_bag         year  nonbearing_trees  bearing_trees  \
# count  114.000000   114.000000        109.000000     109.000000
# mean     8.812281  2012.552632        994.495413    5646.926606
# std      9.051550     6.265642        310.338484     372.684151
# min      0.500000  2002.000000        466.000000    4465.000000
# 25%      2.600000  2007.000000        679.000000    5640.000000
# 50%      4.750000  2013.000000       1050.000000    5735.000000
# 75%     12.175000  2018.000000       1185.000000    5810.000000
# max     34.800000  2023.000000       1510.000000    6200.000000
#
#        nonbear_hectares  bearing_hectares  bearing_trees_per_hectare  \
# count        109.000000        109.000000                 109.000000
# mean         298.055046       2146.513761                2639.027523
# std           97.572559         96.699000                 245.497999
# min          148.000000       2010.000000                2106.000000
# ...

# %%
# TODO: display the null values in your dataframe
coffee.isnull()
# Out:
#      country  subdivision   type  60kgs_bag   year  nonbearing_trees  \
# 0      False        False  False      False  False             False
# 1      False        False  False      False  False             False
# 2      False        False  False      False  False             False
# 3      False        False  False      False  False             False
# 4      False        False  False      False  False             False
# ..       ...          ...    ...        ...    ...               ...
# 109    False        False  False      False  False             False
# 110    False        False  False      False  False             False
# 111    False        False  False      False  False             False
# 112    False        False  False      False  False             False
# 113    False        False  False      False  False             False
#
#      bearing_trees  nonbear_hectares  bearing_hectares  \
# 0            False             False             False
# ...

# %%
# TODO: drop your null values
coffee_mg = coffee_mg.dropna()
coffee_mg.isnull()
# Out:
#      country  subdivision   type  60kgs_bag   year  nonbearing_trees  \
# 0      False        False  False      False  False             False
# 5      False        False  False      False  False             False
# 10     False        False  False      False  False             False
# 15     False        False  False      False  False             False
# 20     False        False  False      False  False             False
# 25     False        False  False      False  False             False
# 30     False        False  False      False  False             False
# 35     False        False  False      False  False             False
# 40     False        False  False      False  False             False
# 45     False        False  False      False  False             False
# 50     False        False  False      False  False             False
# 55     False        False  False      False  False             False
# 60     False        False  False      False  False             False
# ...

# %%
print(coffee_mg.isnull().sum())
# Out:
# country                         0
# subdivision                     0
# type                            0
# 60kgs_bag                       0
# year                            0
# nonbearing_trees                0
# bearing_trees                   0
# nonbear_hectares                0
# bearing_hectares                0
# bearing_trees_per_hectare       0
# nonbearing_trees_per_hectare    0
# dtype: int64

# %%
# TODO: Select only Minas Gerais
coffee_mg = coffee[coffee["subdivision"] == "Minas Gerais"]
coffee_mg
# Out:
#     country   subdivision     type  60kgs_bag  year  nonbearing_trees  \
# 0    Brazil  Minas Gerais  Arabica      16.20  2002            1500.0
# 5    Brazil  Minas Gerais  Arabica      26.70  2003            1125.0
# 10   Brazil  Minas Gerais  Arabica      14.40  2004             631.0
# 15   Brazil  Minas Gerais  Arabica      21.40  2005             466.0
# 20   Brazil  Minas Gerais  Arabica      16.30  2006             581.0
# 25   Brazil  Minas Gerais  Arabica      23.70  2007             563.0
# 30   Brazil  Minas Gerais  Arabica      16.85  2008             679.0
# 35   Brazil  Minas Gerais  Arabica      25.55  2009             663.0
# 40   Brazil  Minas Gerais  Arabica      22.10  2010             873.0
# 45   Brazil  Minas Gerais  Arabica      28.50  2011             815.0
# 50   Brazil  Minas Gerais  Arabica      23.50  2012             835.0
# 55   Brazil  Minas Gerais  Arabica      28.50  2013            1000.0
# ...

# %%
coffee_mg.info()
coffee_mg.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 0 to 109
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       22 non-null     object
#  1   subdivision                   22 non-null     object
#  2   type                          22 non-null     object
#  3   60kgs_bag                     22 non-null     float64
#  4   year                          22 non-null     int64
#  5   nonbearing_trees              21 non-null     float64
#  6   bearing_trees                 21 non-null     float64
#  7   nonbear_hectares              21 non-null     float64
#  8   bearing_hectares              21 non-null     float64
#  9   bearing_trees_per_hectare     21 non-null     float64
#  10  nonbearing_trees_per_hectare  21 non-null     float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 2.1+ KB
# ...

# %%
# TODO: BEGIN YOUR EDA!
#Histogram of Nonbearing Trees and Bearing trees 
#Histogram of Nonbearing Trees
coffee_mg['nonbearing_trees'].hist(bins=20)
plt.title('Nonbearing Trees Frequency')
plt.xlabel('Amount of Nonbearing Trees')
plt.show()

#Histogram of Bearing Trees
coffee_mg['bearing_trees'].hist(bins=20)
plt.title('Bearing Trees Frequency')
plt.xlabel('Amount of Bearing Trees')
plt.show()

# %%
#Histogram of Nonbearing Trees Per Hectare and Bearing trees Per Hectare
#Histogram of Nonbearing Trees Per Hectare
coffee_mg['nonbearing_trees_per_hectare'].hist(bins=20)
plt.title('Nonbearing Trees Per Hectare Frequency')
plt.xlabel('Amount of Nonbearing Trees Per Hectare')
plt.show()

#Histogram of Bearing Trees Per Hectare
coffee_mg['bearing_trees_per_hectare'].hist(bins=20)
plt.title('Bearing Trees Frequency')
plt.xlabel('Amount of Bearing Trees Per Hectare')
plt.show()

# %% [markdown]
# ## Reflections
#
# Answer each question based on the visualizations that you've generated.
#
# Remember, you must justify your answers with proof! Look back to W6D3 for more context.

# %% [markdown]
# How is bearing trees changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The bearing trees looks like it is increasing across the years for Minas Gerais. It looks like a normal distribution and a linear relationship. It went from 4500 bearing trees in 2002 to 6250 bearing trees in 2021.

# %%
#Lineplot
coffee_mg.plot(x='year', y='bearing_trees', kind='line')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# How is bearing hectares changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The bearing hectares looks like it is decreasing across the years for Minas Gerais. The distrubtion looks normal. It went from 2350 bearing hectares in 2003 to 2050 bearing hectares in 2020. It isn't a linear relationship since it is decreasing.

# %%
#Lineplot
coffee_mg.plot(x='year', y='bearing_hectares', kind='line')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# How is the count of million 60kgs bags of coffee changing across the years for Minas Gerais? Is this increasing or decreasing? What is the distribution of this variable? Is it normal?
#
# The count of million 60kgs bags of coffee looks like it is increasing across the years for Minas Gerais. The distrubtion looks normal and a linear relationship.

# %%
#Lineplot
coffee_mg.plot(x='year', y='60kgs_bag', kind='line')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# What is the relationship between bearing_trees and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between bearing_trees and 60kgs_bag leads to a positive correlation. 60kgs_bag rounds to 0.7 which is close to 1 instead of 0. It is a linear relationship.

# %%
#Scatterplot
coffee_mg.plot(x='bearing_trees', y='60kgs_bag', kind='scatter')

#Pearson's correlation coefficient
coffee_mg[["bearing_trees", "60kgs_bag"]].corr()
# Out:
#                bearing_trees  60kgs_bag
# bearing_trees       1.000000   0.655343
# 60kgs_bag           0.655343   1.000000

# %% [markdown]
# What is the relationship between bearing_hectares and 60kgs_bag? How *strong* is this relationship? Use pearson's correlation coefficient.
#
# The relationship between bearing_trees and 60kgs_bag leads to a negative correlation. 60kgs_bag rounds to -0.5 which is close to -1 instead of 0 or 1. It isn't a linear relationship.

# %%
#Scatterplot
coffee_mg.plot(x='bearing_hectares', y='60kgs_bag', kind='scatter')

#Pearson's correlation coefficient
coffee_mg[["bearing_hectares", "60kgs_bag"]].corr()
# Out:
#                   bearing_hectares  60kgs_bag
# bearing_hectares           1.00000   -0.48092
# 60kgs_bag                 -0.48092    1.00000
